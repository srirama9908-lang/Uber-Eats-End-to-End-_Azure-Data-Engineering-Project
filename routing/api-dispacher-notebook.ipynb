# %%
dbutils.widgets.text("table_name","")
table_name=dbutils.widgets.get("table_name")
print("================================")
print("TABLE NAME RECEIVED:")
print(repr(table_name))
print("================================")

# Clean value
table_name = table_name.strip().lower()
notebook_map = {
    "customers": "Silver_Customers",
    "restaurants": "Silver_Restaurants",
    "menu_items": "Silver_Menu_Items",
    "orders": "Silver_Orders",
    "order_items": "Silver_Order_Items",
    "payments": "Silver_Payments",
    "deliveries": "Silver_Deliveries",
    "ratings": "Silver_Ratings",
    "order_status": "Silver_Order_Status"
}

# CHECK FOR TABLE EXSISTENCE
if table_name not in notebook_map:
     raise ValueError(f"Unsupported table: {table_name}")
target_notebook  = notebook_map[table_name]
print("table_name:", table_name)
print("target_notebook:", target_notebook)
dbutils.notebook.run(f"/Workspace/Users/sivana9908_gmail.com#ext#@sivana9908gmail.onmicrosoft.com/Uber-Eats-End-to-End-_Azure-Data-Engineering-Project/notebooks/{target_notebook}",0)
